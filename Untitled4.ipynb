# %%
! pip install streamlit -q

# %%
# !wget -q -O - ipv4.icanhazip.com
# Out:
# 104.196.194.55

# %%
! streamlit run app.py & npx localtunnel --port 8501
# Out:
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
#
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.12:8501
#   External URL: http://104.196.194.55:8501
#
# npx: installed 22 in 2.619s
# your url is: https://good-singers-create.loca.lt
# 2024-05-15 07:22:46.612 `st.cache` is deprecated. Please use one of Streamlit's new caching commands,
# `st.cache_data` or `st.cache_resource`.
#
# More information [in our docs](https://docs.streamlit.io/library/advanced-features/caching).
# 2024-05-15 07:22:46.614 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 600, in _run_script
#     exec(code, module.__dict__)
#   File "/content/app.py", line 29, in <module>
#     main()
#   File "/content/app.py", line 23, in main
#     classifier = sidebar()
# NameError: name 'sidebar' is not defined
# 2024-05-15 07:24:33.389 `st.cache` is deprecated. Please use one of Streamlit's new caching commands,
# `st.cache_data` or `st.cache_resource`.
#
# More information [in our docs](https://docs.streamlit.io/library/advanced-features/caching).
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
#  14  gross margin percentage  1000 non-null   float64
#  15  gross income             1000 non-null   float64
#  16  Rating                   1000 non-null   float64
# dtypes: float64(7), int64(1), object(9)
# memory usage: 132.9+ KB
# 2024-05-15 07:24:33.465 Serialization of dataframe to Arrow table was unsuccessful due to: ("Could not convert dtype('O') with type numpy.dtypes.ObjectDType: did not recognize Python value type when inferring an Arrow data type", 'Conversion failed for column 0 with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# 2024-05-15 07:24:44.411 Uncaught app exception
# streamlit.runtime.legacy_caching.caching.CachedObjectMutationWarning: Return value of `load_data()` was mutated between runs.
#
# By default, Streamlit's cache should be treated as immutable, or it may behave
# in unexpected ways. You received this warning because Streamlit detected
# that an object returned by `load_data()` was mutated outside of `load_data()`.
#
# How to fix this:
# * If you did not mean to mutate that return value:
#   - If possible, inspect your code to find and remove that mutation.
#   - Otherwise, you could also clone the returned value so you can freely
#     mutate it.
# * If you actually meant to mutate the return value and know the consequences of
# doing so, annotate the function with `@st.cache(allow_output_mutation=True)`.
#
# For more information and detailed solutions check out [our documentation.]
# (https://docs.streamlit.io/library/advanced-features/caching)
#
# 2024-05-15 07:24:44.414 `st.cache` is deprecated. Please use one of Streamlit's new caching commands,
# `st.cache_data` or `st.cache_resource`.
#
# More information [in our docs](https://docs.streamlit.io/library/advanced-features/caching).
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   int64
#  1   Branch                   1000 non-null   int64
#  2   City                     1000 non-null   int64
#  3   Customer type            1000 non-null   int64
#  4   Gender                   1000 non-null   int64
#  5   Product line             1000 non-null   int64
#  6   Unit price               1000 non-null   int64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   int64
#  9   Total                    1000 non-null   int64
#  10  Date                     1000 non-null   int64
#  11  Time                     1000 non-null   int64
#  12  Payment                  1000 non-null   int64
#  13  cogs                     1000 non-null   int64
#  14  gross margin percentage  1000 non-null   int64
#  15  gross income             1000 non-null   int64
#  16  Rating                   1000 non-null   int64
# dtypes: int64(17)
# memory usage: 132.9 KB
# 2024-05-15 07:24:44.477 Serialization of dataframe to Arrow table was unsuccessful due to: ("Could not convert dtype('int64') with type numpy.dtypes.Int64DType: did not recognize Python value type when inferring an Arrow data type", 'Conversion failed for column 0 with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# 2024-05-15 07:27:20.742 Uncaught app exception
# streamlit.runtime.legacy_caching.caching.CachedObjectMutationWarning: Return value of `load_data()` was mutated between runs.
#
# By default, Streamlit's cache should be treated as immutable, or it may behave
# in unexpected ways. You received this warning because Streamlit detected
# that an object returned by `load_data()` was mutated outside of `load_data()`.
#
# How to fix this:
# * If you did not mean to mutate that return value:
#   - If possible, inspect your code to find and remove that mutation.
#   - Otherwise, you could also clone the returned value so you can freely
#     mutate it.
# * If you actually meant to mutate the return value and know the consequences of
# doing so, annotate the function with `@st.cache(allow_output_mutation=True)`.
#
# For more information and detailed solutions check out [our documentation.]
# (https://docs.streamlit.io/library/advanced-features/caching)
#
# 2024-05-15 07:27:20.746 `st.cache` is deprecated. Please use one of Streamlit's new caching commands,
# `st.cache_data` or `st.cache_resource`.
#
# More information [in our docs](https://docs.streamlit.io/library/advanced-features/caching).
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   int64
#  1   Branch                   1000 non-null   int64
#  2   City                     1000 non-null   int64
#  3   Customer type            1000 non-null   int64
#  4   Gender                   1000 non-null   int64
#  5   Product line             1000 non-null   int64
#  6   Unit price               1000 non-null   int64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   int64
#  9   Total                    1000 non-null   int64
#  10  Date                     1000 non-null   int64
#  11  Time                     1000 non-null   int64
#  12  Payment                  1000 non-null   int64
#  13  cogs                     1000 non-null   int64
#  14  gross margin percentage  1000 non-null   int64
#  15  gross income             1000 non-null   int64
#  16  Rating                   1000 non-null   int64
# dtypes: int64(17)
# memory usage: 132.9 KB
# 2024-05-15 07:27:20.818 Serialization of dataframe to Arrow table was unsuccessful due to: ("Could not convert dtype('int64') with type numpy.dtypes.Int64DType: did not recognize Python value type when inferring an Arrow data type", 'Conversion failed for column 0 with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# 2024-05-15 07:28:08.853 Session with id d3b19829-4c09-49a3-b4d5-96d0dc51ff07 is already connected! Connecting to a new session.
# 2024-05-15 07:28:09.385 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/legacy_caching/caching.py", line 623, in get_or_create_cached_value
#     return_value = _read_from_cache(
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/legacy_caching/caching.py", line 380, in _read_from_cache
#     raise e
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/legacy_caching/caching.py", line 365, in _read_from_cache
#     return _read_from_mem_cache(
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/legacy_caching/caching.py", line 282, in _read_from_mem_cache
#     raise CacheKeyNotFoundError("Key not found in mem cache")
# streamlit.runtime.legacy_caching.caching.CacheKeyNotFoundError: Key not found in mem cache
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 600, in _run_script
#     exec(code, module.__dict__)
#   File "/content/app.py", line 144, in <module>
#     main()
#   File "/content/app.py", line 137, in main
#     data = load_data()
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/legacy_caching/caching.py", line 656, in wrapped_func
#     return get_or_create_cached_value()
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/legacy_caching/caching.py", line 637, in get_or_create_cached_value
#     return_value = non_optional_func(*args, **kwargs)
# TypeError: load_data() missing 1 required positional argument: 'file'
# 2024-05-15 07:28:58.822 `st.cache` is deprecated. Please use one of Streamlit's new caching commands,
# `st.cache_data` or `st.cache_resource`.
#
# More information [in our docs](https://docs.streamlit.io/library/advanced-features/caching).
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
#  14  gross margin percentage  1000 non-null   float64
#  15  gross income             1000 non-null   float64
#  16  Rating                   1000 non-null   float64
# dtypes: float64(7), int64(1), object(9)
# memory usage: 132.9+ KB
# 2024-05-15 07:28:58.893 Serialization of dataframe to Arrow table was unsuccessful due to: ("Could not convert dtype('O') with type numpy.dtypes.ObjectDType: did not recognize Python value type when inferring an Arrow data type", 'Conversion failed for column 0 with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# 2024-05-15 07:29:02.504 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 600, in _run_script
#     exec(code, module.__dict__)
#   File "/content/app.py", line 147, in <module>
#     main()
#   File "/content/app.py", line 142, in main
#     visualize_data(data)
#   File "/content/app.py", line 68, in visualize_data
#     correlation_heatmap(data)
#   File "/content/app.py", line 96, in correlation_heatmap
#     sns.heatmap(data.corr(), annot=True, cmap='coolwarm')
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/frame.py", line 10054, in corr
#     mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/frame.py", line 1838, in to_numpy
#     result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py", line 1732, in as_array
#     arr = self._interleave(dtype=dtype, na_value=na_value)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py", line 1794, in _interleave
#     result[rl.indexer] = arr
# ValueError: could not convert string to float: '750-67-8428'
# 2024-05-15 07:29:09.851 Session with id cd5033a4-3e09-4822-935d-5a35f2e8a4a7 is already connected! Connecting to a new session.
# 2024-05-15 07:29:18.661 `st.cache` is deprecated. Please use one of Streamlit's new caching commands,
# `st.cache_data` or `st.cache_resource`.
#
# More information [in our docs](https://docs.streamlit.io/library/advanced-features/caching).
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
#  14  gross margin percentage  1000 non-null   float64
#  15  gross income             1000 non-null   float64
#  16  Rating                   1000 non-null   float64
# dtypes: float64(7), int64(1), object(9)
# memory usage: 132.9+ KB
# 2024-05-15 07:29:18.708 Serialization of dataframe to Arrow table was unsuccessful due to: ("Could not convert dtype('O') with type numpy.dtypes.ObjectDType: did not recognize Python value type when inferring an Arrow data type", 'Conversion failed for column 0 with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# 2024-05-15 07:29:22.406 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 600, in _run_script
#     exec(code, module.__dict__)
#   File "/content/app.py", line 147, in <module>
#     main()
#   File "/content/app.py", line 142, in main
#     visualize_data(data)
#   File "/content/app.py", line 68, in visualize_data
#     correlation_heatmap(data)
#   File "/content/app.py", line 96, in correlation_heatmap
#     sns.heatmap(data.corr(), annot=True, cmap='coolwarm')
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/frame.py", line 10054, in corr
#     mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/frame.py", line 1838, in to_numpy
#     result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py", line 1732, in as_array
#     arr = self._interleave(dtype=dtype, na_value=na_value)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py", line 1794, in _interleave
#     result[rl.indexer] = arr
# ValueError: could not convert string to float: '750-67-8428'
# 2024-05-15 07:30:07.583 `st.cache` is deprecated. Please use one of Streamlit's new caching commands,
# `st.cache_data` or `st.cache_resource`.
#
# More information [in our docs](https://docs.streamlit.io/library/advanced-features/caching).
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
#  14  gross margin percentage  1000 non-null   float64
#  15  gross income             1000 non-null   float64
#  16  Rating                   1000 non-null   float64
# dtypes: float64(7), int64(1), object(9)
# memory usage: 132.9+ KB
# 2024-05-15 07:30:07.636 Serialization of dataframe to Arrow table was unsuccessful due to: ("Could not convert dtype('O') with type numpy.dtypes.ObjectDType: did not recognize Python value type when inferring an Arrow data type", 'Conversion failed for column 0 with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# 2024-05-15 07:30:12.384 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 600, in _run_script
#     exec(code, module.__dict__)
#   File "/content/app.py", line 151, in <module>
#     main()
#   File "/content/app.py", line 147, in main
#     train_model(data)
# TypeError: train_model() missing 1 required positional argument: 'classifier'
# 2024-05-15 07:32:27.935 `st.cache` is deprecated. Please use one of Streamlit's new caching commands,
# `st.cache_data` or `st.cache_resource`.
#
# More information [in our docs](https://docs.streamlit.io/library/advanced-features/caching).
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
#  14  gross margin percentage  1000 non-null   float64
#  15  gross income             1000 non-null   float64
#  16  Rating                   1000 non-null   float64
# dtypes: float64(7), int64(1), object(9)
# memory usage: 132.9+ KB
# 2024-05-15 07:32:28.100 Serialization of dataframe to Arrow table was unsuccessful due to: ("Could not convert dtype('O') with type numpy.dtypes.ObjectDType: did not recognize Python value type when inferring an Arrow data type", 'Conversion failed for column 0 with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
#  14  gross margin percentage  1000 non-null   float64
#  15  gross income             1000 non-null   float64
#  16  Rating                   1000 non-null   float64
# dtypes: float64(7), int64(1), object(9)
# memory usage: 132.9+ KB
# 2024-05-15 07:32:34.534 Serialization of dataframe to Arrow table was unsuccessful due to: ("Could not convert dtype('O') with type numpy.dtypes.ObjectDType: did not recognize Python value type when inferring an Arrow data type", 'Conversion failed for column 0 with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# 2024-05-15 07:33:02.478 Uncaught app exception
# streamlit.runtime.legacy_caching.caching.CachedObjectMutationWarning: Return value of `load_data()` was mutated between runs.
#
# By default, Streamlit's cache should be treated as immutable, or it may behave
# in unexpected ways. You received this warning because Streamlit detected
# that an object returned by `load_data()` was mutated outside of `load_data()`.
#
# How to fix this:
# * If you did not mean to mutate that return value:
#   - If possible, inspect your code to find and remove that mutation.
#   - Otherwise, you could also clone the returned value so you can freely
#     mutate it.
# * If you actually meant to mutate the return value and know the consequences of
# doing so, annotate the function with `@st.cache(allow_output_mutation=True)`.
#
# For more information and detailed solutions check out [our documentation.]
# (https://docs.streamlit.io/library/advanced-features/caching)
#
# 2024-05-15 07:33:02.481 `st.cache` is deprecated. Please use one of Streamlit's new caching commands,
# `st.cache_data` or `st.cache_resource`.
#
# More information [in our docs](https://docs.streamlit.io/library/advanced-features/caching).
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   int64
#  1   Branch                   1000 non-null   int64
#  2   City                     1000 non-null   int64
#  3   Customer type            1000 non-null   int64
#  4   Gender                   1000 non-null   int64
#  5   Product line             1000 non-null   int64
#  6   Unit price               1000 non-null   int64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   int64
#  9   Total                    1000 non-null   int64
#  10  Date                     1000 non-null   int64
#  11  Time                     1000 non-null   int64
#  12  Payment                  1000 non-null   int64
#  13  cogs                     1000 non-null   int64
#  14  gross margin percentage  1000 non-null   int64
#  15  gross income             1000 non-null   int64
#  16  Rating                   1000 non-null   int64
# dtypes: int64(17)
# memory usage: 132.9 KB
# 2024-05-15 07:33:02.546 Serialization of dataframe to Arrow table was unsuccessful due to: ("Could not convert dtype('int64') with type numpy.dtypes.Int64DType: did not recognize Python value type when inferring an Arrow data type", 'Conversion failed for column 0 with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   int64
#  1   Branch                   1000 non-null   int64
#  2   City                     1000 non-null   int64
#  3   Customer type            1000 non-null   int64
#  4   Gender                   1000 non-null   int64
#  5   Product line             1000 non-null   int64
#  6   Unit price               1000 non-null   int64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   int64
#  9   Total                    1000 non-null   int64
#  10  Date                     1000 non-null   int64
#  11  Time                     1000 non-null   int64
#  12  Payment                  1000 non-null   int64
#  13  cogs                     1000 non-null   int64
#  14  gross margin percentage  1000 non-null   int64
#  15  gross income             1000 non-null   int64
#  16  Rating                   1000 non-null   int64
# dtypes: int64(17)
# memory usage: 132.9 KB
# 2024-05-15 07:33:10.337 Serialization of dataframe to Arrow table was unsuccessful due to: ("Could not convert dtype('int64') with type numpy.dtypes.Int64DType: did not recognize Python value type when inferring an Arrow data type", 'Conversion failed for column 0 with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# 2024-05-15 07:40:10.243 Session with id 800d8bf7-551f-4e62-8d67-0f6692979488 is already connected! Connecting to a new session.
# 2024-05-15 07:40:23.905 Uncaught app exception
# streamlit.runtime.legacy_caching.caching.CachedObjectMutationWarning: Return value of `load_data()` was mutated between runs.
#
# By default, Streamlit's cache should be treated as immutable, or it may behave
# in unexpected ways. You received this warning because Streamlit detected
# that an object returned by `load_data()` was mutated outside of `load_data()`.
#
# How to fix this:
# * If you did not mean to mutate that return value:
#   - If possible, inspect your code to find and remove that mutation.
#   - Otherwise, you could also clone the returned value so you can freely
#     mutate it.
# * If you actually meant to mutate the return value and know the consequences of
# doing so, annotate the function with `@st.cache(allow_output_mutation=True)`.
#
# For more information and detailed solutions check out [our documentation.]
# (https://docs.streamlit.io/library/advanced-features/caching)
#
# 2024-05-15 07:40:23.906 `st.cache` is deprecated. Please use one of Streamlit's new caching commands,
# `st.cache_data` or `st.cache_resource`.
#
# More information [in our docs](https://docs.streamlit.io/library/advanced-features/caching).
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   int64
#  1   Branch                   1000 non-null   int64
#  2   City                     1000 non-null   int64
#  3   Customer type            1000 non-null   int64
#  4   Gender                   1000 non-null   int64
#  5   Product line             1000 non-null   int64
#  6   Unit price               1000 non-null   int64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   int64
#  9   Total                    1000 non-null   int64
#  10  Date                     1000 non-null   int64
#  11  Time                     1000 non-null   int64
#  12  Payment                  1000 non-null   int64
#  13  cogs                     1000 non-null   int64
#  14  gross margin percentage  1000 non-null   int64
#  15  gross income             1000 non-null   int64
#  16  Rating                   1000 non-null   int64
# dtypes: int64(17)
# memory usage: 132.9 KB
# 2024-05-15 07:40:23.973 Serialization of dataframe to Arrow table was unsuccessful due to: ("Could not convert dtype('int64') with type numpy.dtypes.Int64DType: did not recognize Python value type when inferring an Arrow data type", 'Conversion failed for column 0 with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# 2024-05-15 07:41:10.252 Session with id 7beaf18b-5e87-42b5-bfb8-eb838cb52b65 is already connected! Connecting to a new session.
# 2024-05-15 07:42:14.309 Uncaught app exception
# streamlit.runtime.legacy_caching.caching.CachedObjectMutationWarning: Return value of `load_data()` was mutated between runs.
#
# By default, Streamlit's cache should be treated as immutable, or it may behave
# in unexpected ways. You received this warning because Streamlit detected
# that an object returned by `load_data()` was mutated outside of `load_data()`.
#
# How to fix this:
# * If you did not mean to mutate that return value:
#   - If possible, inspect your code to find and remove that mutation.
#   - Otherwise, you could also clone the returned value so you can freely
#     mutate it.
# * If you actually meant to mutate the return value and know the consequences of
# doing so, annotate the function with `@st.cache(allow_output_mutation=True)`.
#
# For more information and detailed solutions check out [our documentation.]
# (https://docs.streamlit.io/library/advanced-features/caching)
#
# 2024-05-15 07:42:14.311 `st.cache` is deprecated. Please use one of Streamlit's new caching commands,
# `st.cache_data` or `st.cache_resource`.
#
# More information [in our docs](https://docs.streamlit.io/library/advanced-features/caching).
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   int64
#  1   Branch                   1000 non-null   int64
#  2   City                     1000 non-null   int64
#  3   Customer type            1000 non-null   int64
#  4   Gender                   1000 non-null   int64
#  5   Product line             1000 non-null   int64
#  6   Unit price               1000 non-null   int64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   int64
#  9   Total                    1000 non-null   int64
#  10  Date                     1000 non-null   int64
#  11  Time                     1000 non-null   int64
#  12  Payment                  1000 non-null   int64
#  13  cogs                     1000 non-null   int64
#  14  gross margin percentage  1000 non-null   int64
#  15  gross income             1000 non-null   int64
#  16  Rating                   1000 non-null   int64
# dtypes: int64(17)
# memory usage: 132.9 KB
# 2024-05-15 07:42:14.373 Serialization of dataframe to Arrow table was unsuccessful due to: ("Could not convert dtype('int64') with type numpy.dtypes.Int64DType: did not recognize Python value type when inferring an Arrow data type", 'Conversion failed for column 0 with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# 2024-05-15 07:42:41.110 Uncaught app exception
# streamlit.runtime.legacy_caching.caching.CachedObjectMutationWarning: Return value of `load_data()` was mutated between runs.
#
# By default, Streamlit's cache should be treated as immutable, or it may behave
# in unexpected ways. You received this warning because Streamlit detected
# that an object returned by `load_data()` was mutated outside of `load_data()`.
#
# How to fix this:
# * If you did not mean to mutate that return value:
#   - If possible, inspect your code to find and remove that mutation.
#   - Otherwise, you could also clone the returned value so you can freely
#     mutate it.
# * If you actually meant to mutate the return value and know the consequences of
# doing so, annotate the function with `@st.cache(allow_output_mutation=True)`.
#
# For more information and detailed solutions check out [our documentation.]
# (https://docs.streamlit.io/library/advanced-features/caching)
#
# 2024-05-15 07:42:41.116 `st.cache` is deprecated. Please use one of Streamlit's new caching commands,
# `st.cache_data` or `st.cache_resource`.
#
# More information [in our docs](https://docs.streamlit.io/library/advanced-features/caching).
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   int64
#  1   Branch                   1000 non-null   int64
#  2   City                     1000 non-null   int64
#  3   Customer type            1000 non-null   int64
#  4   Gender                   1000 non-null   int64
#  5   Product line             1000 non-null   int64
#  6   Unit price               1000 non-null   int64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   int64
#  9   Total                    1000 non-null   int64
#  10  Date                     1000 non-null   int64
#  11  Time                     1000 non-null   int64
#  12  Payment                  1000 non-null   int64
#  13  cogs                     1000 non-null   int64
#  14  gross margin percentage  1000 non-null   int64
#  15  gross income             1000 non-null   int64
#  16  Rating                   1000 non-null   int64
# dtypes: int64(17)
# memory usage: 132.9 KB
# 2024-05-15 07:42:41.197 Serialization of dataframe to Arrow table was unsuccessful due to: ("Could not convert dtype('int64') with type numpy.dtypes.Int64DType: did not recognize Python value type when inferring an Arrow data type", 'Conversion failed for column 0 with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.

# %%
from google.colab import drive
drive.mount('/content/drive')
